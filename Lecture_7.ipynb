# %% [markdown]
# # Lecture 7

# %% [markdown]
# diabetes.csv dataset
#
# Pima Indians Diabetes Database
# - The datasets consist of several medical predictor (independent) variables and one target (dependent) variable, Outcome.
# - Independent variables include the number of pregnancies the patient has had, their BMI, insulin level, age, and so on.

# %%
# !pip install scikeras

import pandas as pd
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout # dense is a fully connected layer

from scikeras.wrappers import KerasClassifier
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import  LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, precision_recall_curve, roc_curve
from sklearn.model_selection import train_test_split,  StratifiedKFold, GridSearchCV
# Out:
# Requirement already satisfied: scikeras in /usr/local/lib/python3.10/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from scikeras) (3.4.1)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from scikeras) (1.5.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (13.8.0)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (3.11.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.12.1)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (0.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras>=3.2.0->scikeras) (24.1)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.5.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from optree->keras>=3.2.0->scikeras) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras>=3.2.0->scikeras) (2.16.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %%
data = pd.read_csv('diabetes.csv')
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
y = data['Outcome']
print(f'Number of 0: {(y == 0).sum()}')
print(f'Number of 1: {(y == 1).sum()}')
data.drop(['Outcome'], axis=1, inplace=True)
colnames = data.columns.values.tolist()
colnames
# Out:
# Number of 0: 500
# Number of 1: 268
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age']

# %%
sscaler = StandardScaler()
mmscaler = MinMaxScaler()
diabet_tf = ColumnTransformer(
    transformers=[
        ('other', sscaler, colnames[:-1]),
        ('Age', mmscaler, ['Age'])
    ],
    verbose_feature_names_out=False
)
diabet_tf.fit_transform(data)
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075, ...,  0.20401277,
#          0.46849198,  0.48333333],
#        [-0.84488505, -1.12339636, -0.16054575, ..., -0.68442195,
#         -0.36506078,  0.16666667],
#        [ 1.23388019,  1.94372388, -0.26394125, ..., -1.10325546,
#          0.60439732,  0.18333333],
#        ...,
#        [ 0.3429808 ,  0.00330087,  0.14964075, ..., -0.73518964,
#         -0.68519336,  0.15      ],
#        [-0.84488505,  0.1597866 , -0.47073225, ..., -0.24020459,
#         -0.37110101,  0.43333333],
#        [-0.84488505, -0.8730192 ,  0.04624525, ..., -0.20212881,
#         -0.47378505,  0.03333333]])

# %%
new_data = pd.DataFrame(diabet_tf.transform(data), columns=diabet_tf.get_feature_names_out())
new_data.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.639947  0.848324       0.149641       0.907270 -0.692891  0.204013
# 1    -0.844885 -1.123396      -0.160546       0.530902 -0.692891 -0.684422
# 2     1.233880  1.943724      -0.263941      -1.288212 -0.692891 -1.103255
# 3    -0.844885 -0.998208      -0.160546       0.154533  0.123302 -0.494043
# 4    -1.141852  0.504055      -1.504687       0.907270  0.765836  1.409746
#
#    DiabetesPedigreeFunction       Age
# 0                  0.468492  0.483333
# 1                 -0.365061  0.166667
# 2                  0.604397  0.183333
# 3                 -0.920763  0.000000
# 4                  5.484909  0.200000

# %% [markdown]
# We now evaluate a Logistic Regression model trained on such data.

# %%
parameters={
    'C': [0.0001, 0.001, 0.01, 0.1, 1.0, 10.0, 100.0, 1000.0],
    'penalty': ['l1', 'l2']
}

skf = StratifiedKFold(n_splits=3)
test_f1 = []
test_acc = []

for train_index, test_index in skf.split(data, y):
    x_train, y_train = data.iloc[train_index,:], y[train_index]
    x_test, y_test = data.iloc[test_index,:], y[test_index]
    diabet_tf.fit(x_train)
    x_train = pd.DataFrame(diabet_tf.transform(x_train), columns=diabet_tf.get_feature_names_out())
    x_test = pd.DataFrame(diabet_tf.transform(x_test), columns=diabet_tf.get_feature_names_out())
    cls = LogisticRegression(solver='liblinear')
    GS = GridSearchCV(estimator=cls,
                      param_grid=parameters,
                      scoring='f1',
                      refit=True,
                      cv=3,
                      verbose=0)
    result = GS.fit(x_train, y_train)

    print(f'Best score got by the best estimator: {result.best_score_}')
    print(f'Configuration for the best estimator/classifier: {result.best_params_}')

    best_model = result.best_estimator_
    prediction = best_model.predict(x_test)
    test_f1.append(f1_score(y_test, prediction))
    test_acc.append(accuracy_score(y_test, prediction))

print(f"Mean f1 test:{np.mean(test_f1)} +/-:{np.std(test_f1)}")
print(f"Mean Accuracy test:{np.mean(test_acc)} +/-:{np.std(test_acc)}")
# Out:
# Best score got by the best estimator: 0.6565275957477792
# Configuration for the best estimator/classifier: {'C': 0.0001, 'penalty': 'l2'}
# Best score got by the best estimator: 0.6566685531031881
# Configuration for the best estimator/classifier: {'C': 0.001, 'penalty': 'l2'}
# Best score got by the best estimator: 0.6331841010187976
# Configuration for the best estimator/classifier: {'C': 0.1, 'penalty': 'l2'}
# Mean f1 test:0.6359184352403596 +/-:0.018128061310017263
# Mean Accuracy test:0.7669270833333334 +/-:0.021236336497786574

# %% [markdown]
# We now use a keras. model for model selection in scikit-learn.
#
# Keras models can be used in scikit-learn by wrapping them with the KerasClassifier, KerasRegressor classes from module SciKeras.
#
# We need to define a method (e.g., create_model) to create our model. Then we feed it as an argument model of KerasClassifier constructor. (KerasClassifier(model=create_model)

# %% [markdown]
# We define our create_model() method.
#
# - Argument which does not have defalut value must be specified in the text KerasClassifier() call as individual argument
# - Optionally, also in the grid for grid search
# - Kernel_regularizer performs the weight regularization.

# %%
np.random.seed(42) # for reproducibility
tf.random.set_seed(43)
input_shape = data.shape[1]
print(f"input_shape:{input_shape}, num_classes:{len(np.unique(y))}")
# Out:
# input_shape:8, num_classes:2

# %%
def create_model(nhid1, nhid2, # number of hidden neurons in hidden layers 1, 2
                 learning_rate=10**-1, # learning rate to be used by the optimizer
                 loss='BinaryCrossentropy', # loss function
                 hid_act='relu', # activation function for hidden layers
                 out_act='sigmoid', # activation function for output layer
                 dropout_rate=0, # the rate of dropout to be used
                 weight_reg=None):
    model = Sequential()
    model.add(Dense(nhid1,
                    input_shape=(input_shape,),
                    activation=hid_act,
                    kernel_regularizer=weight_reg))
    # set dropout regularization
    model.add(Dropout(dropout_rate))
    model.add(Dense(nhid2,
                    activation=hid_act,
                    kernel_regularizer=weight_reg))
    model.add(Dropout(dropout_rate))
    model.add(Dense(1, activation=out_act))
    model.compile(loss=loss,
                  optimizer=tf.keras.optimizers.SGD(learning_rate=learning_rate),
                  metrics=['accuracy'])
    return model

# %% [markdown]
# ### Instantiating the model

# %%
# wrapper class for scikit_learn API
model = KerasClassifier(model=create_model,
                      nhid1=50,
                      nhid2=50,
                      epochs=20)
model.fit(new_data, y) # learning the model on all data
prediction = model.predict(new_data)
print(f"Training accuracy: {accuracy_score(y, prediction)}")
print(f"Training F: {f1_score(y, prediction)}")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.5276 - loss: 0.6896
# Epoch 2/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7367 - loss: 0.5556
# Epoch 3/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7448 - loss: 0.5213
# Epoch 4/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7579 - loss: 0.5130
# Epoch 5/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7603 - loss: 0.5082
# Epoch 6/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7668 - loss: 0.5035
# Epoch 7/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7668 - loss: 0.4995
# Epoch 8/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7698 - loss: 0.4959
# Epoch 9/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7724 - loss: 0.4929
# Epoch 10/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7751 - loss: 0.4900
# Epoch 11/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7754 - loss: 0.4874
# Epoch 12/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7740 - loss: 0.4847
# Epoch 13/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7727 - loss: 0.4822
# Epoch 14/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7727 - loss: 0.4801
# Epoch 15/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7731 - loss: 0.4778
# Epoch 16/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7731 - loss: 0.4758
# Epoch 17/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7730 - loss: 0.4737
# Epoch 18/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7695 - loss: 0.4719
# Epoch 19/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7737 - loss: 0.4700
# Epoch 20/20
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7732 - loss: 0.4682
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Training accuracy: 0.796875
# Training F: 0.6829268292682927

# %% [markdown]
# ### The optimizer

# %% [markdown]
# So far we have used the stochastic gradient descent.

# %%
'''keras.optimizers.SGD(learning_rate=0.01,
                     momentum=0.0,
                     nesterov=False,
                     weight_decay=None,
                     clipnorm=None,
                     clipvalue=None,
                     global_clipnorm=None,
                     use_ema=False,
                     ema_momentum=0.99,
                     ema_overwrite_frequency=None,
                     name='SGD',
                     **kwargs)'''
# Out:
# "keras.optimizers.SGD(learning_rate=0.01,\n                     momentum=0.0,\n                     nesterov=False,\n                     weight_decay=None,\n                     clipnorm=None,\n                     clipvalue=None,\n                     global_clipnorm=None,\n                     use_ema=False,\n                     ema_momentum=0.99,\n                     ema_overwrite_frequency=None,\n                     name='SGD',\n                     **kwargs)"

# %% [markdown]
# - learning_rate: a float, a keras.optimizers.schedules.LearningRateSchedule instance, or acallable that takes no arguments and returns the actualvalue to use. The learnign rate. Deafult is 0.01
# - momentum: float hyperparameter >= 0that acceleratesgradient desccent in the relevant direction and dampens oscillations. 0 is vanilla gradient descent. Default is 0.0
# - nesterov: boolean. Whether to apply Nesterov momentum or not. Default is False.

# %% [markdown]
# ### Model Selection (hyperparameter optimization) using scikit-learn
#
# * We can leverage for instance the ```GridSearchCV```  method!
#
# * We want to tune the number of hidden neurons in the hidden layers
#
#  * However we need to specify their value when calling the KerasClassifier constructor, since they dont have a default value
# * The *learning rate*
# * The *weight regularizer*
# * The *batch_size*
# * The *Activation function*
# * The dropout level
# * Pay attention to the dictionary definition
#  * To tune model arguments, the dictionary name of that argument must start with **"model__"**
#  * The arguments to Keras `fit` method, like batch size and weight regularization, do not need that prefix in the dictionary name

# %%
model = KerasClassifier(model=create_model,
                        nhid1=100,
                        nhid2=50,
                        epochs=15)
# define the grid search parameters for the number of neurons in the hidden layers
nhid1 = [75, 100]
nhid2 = [50, 75]
lr = [10**-4, 10**-3]
weight_reg = [None, 'l2', 'l1']
hid_act = ['relu', 'sigmoid']
batch_size = [16, 32]
dropout = [0, 0.2]
loss = ['BinaryCrossentropy', 'mse']

# dictionary names must start with model__, if it is an argument of the model
# followed by the model argument name

params_grid = dict(model__nhid1=nhid1,
                   model__nhid2=nhid2,
                   model__learning_rate=lr,
                   model__weight_reg=weight_reg,
                   model__hid_act=hid_act,
                   batch_size=batch_size,
                   model__dropout_rate=dropout,
                   model__loss=loss)

# %% [markdown]
# ### Model selection in holdout setting

# %%
X_train, X_test, y_train, y_test = train_test_split(new_data, y,
                                                    test_size=0.1,
                                                    shuffle=True,
                                                    stratify=y)
X_train = pd.DataFrame(diabet_tf.transform(X_train),
                       columns=diabet_tf.get_feature_names_out())
X_test = pd.DataFrame(diabet_tf.transform(X_test),
                      columns=diabet_tf.get_feature_names_out())
GS = GridSearchCV(estimator=model,
                  param_grid=params_grid,
                  n_jobs=-1,
                  scoring='f1',
                  cv=3,
                  verbose=1)
grid_result = GS.fit(X_train, y_train)

# best result
print("Best: %f using %s" % (grid_result.best_score_,
                             grid_result.best_params_))
# Out:
# Fitting 3 folds for each of 384 candidates, totalling 1152 fits
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/backend/fork_exec.py:38: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid = os.fork()
# /usr/local/lib/python3.10/dist-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6463 - loss: 0.2467
# Epoch 2/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.2466
# Epoch 3/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2464
# Epoch 4/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2462
# Epoch 5/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2460
# Epoch 6/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.2458
# Epoch 7/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6463 - loss: 0.2456
# Epoch 8/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2454
# Epoch 9/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2452
# Epoch 10/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2451
# Epoch 11/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6463 - loss: 0.2449
# Epoch 12/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6463 - loss: 0.2447
# Epoch 13/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6463 - loss: 0.2445
# Epoch 14/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.2443
# Epoch 15/15
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6463 - loss: 0.2442
# Best: 0.517163 using {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}

# %%
means = grid_result.cv_results_['mean_test_score']
params = grid_result.cv_results_['params']

# printing results for all combinations
for mean, param in zip(means, params):
    print(f"{mean} \t with: {param}")
# Out:
# 0.18864468864468864 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.05017921146953405 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.38217273954116066 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.43284593134668103 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.17049180327868851 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.2008783602003941 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.16622421890953645 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.21335940045617466 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.2023044911115922 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.2519229460213736 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.2549416155049958 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.2896900695762176 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.05954251789767767 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.1016949152542373 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.04301075268817204 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.1702922434629752 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.04081632653061224 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.022988505747126436 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.17677854274239815 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.23725771773964546 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.15654520917678813 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.03745318352059925 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.3739824046920821 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.12152711786858128 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.01596863645056416 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.159464861379755 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.023718403023860146 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.12407765599254961 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.09280303030303032 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.08333333333333333 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.09419077217308151 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.13118345828626202 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.05673758865248227 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.11193415637860082 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.07260726072607261 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.2047430083144369 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.037037037037037035 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.05017921146953405 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.09953703703703703 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.0924625468164794 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.06060606060606061 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.09542419801335288 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.09706257982120052 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.022727272727272724 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.10344827586206896 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.3451199338296112 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.22219973009446695 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.31789589935657353 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.15492957746478872 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.155668358714044 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.2550136083655637 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.1730769230769231 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.1730769230769231 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.29920304920304924 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.5171629445822994 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.5171629445822994 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.5171629445822994 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.1730769230769231 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.01568627450980392 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.3451199338296112 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.41528343250861255 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.008032128514056226 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.015873015873015872 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.12307692307692308 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.08722741433021806 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0, 'model__hid_act': 'sigmoid', 'model__learning_rate': 0.001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.21972232748094814 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.2562771657447435 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.1197411003236246 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.48212701188509993 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.18810726778080064 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.08666182522391673 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.2857344643456196 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.11631205673758865 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.06802721088435375 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.04395604395604396 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.07333333333333333 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.08176100628930817 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.5145778247840648 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.0 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.34415630051303675 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.2747223410152125 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.292777364110201 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.5171629445822994 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.4715240599855985 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.30630227001194743 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.17204301075268816 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': None}
# 0.31362192764429714 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l2'}
# 0.3708904165244666 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.0001, 'model__loss': 'mse', 'model__nhid1': 100, 'model__nhid2': 75, 'model__weight_reg': 'l1'}
# 0.16565246788370522 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': None}
# 0.11895215183106123 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l2'}
# 0.08146341463414634 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 50, 'model__weight_reg': 'l1'}
# 0.057971014492753624 	 with: {'batch_size': 16, 'model__dropout_rate': 0.2, 'model__hid_act': 'relu', 'model__learning_rate': 0.001, 'model__loss': 'BinaryCrossentropy', 'model__nhid1': 75, 'model__nhid2': 75, 'model__weight_reg': None}
# 0